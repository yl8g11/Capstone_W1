# %% [markdown]
# ## The Most Overrated and Underrated Restaurants Nearby

# %% [markdown]
# ### 2. Data

# %% [markdown]
# First, we will get the latitude and longitude of a location (default is North York, ON).
#
# Second, we are going to use the **explore** function of Foursquare API to extract the venue IDs of recommended restaurants nearby.
#
# Third, based on each venue ID, we will use the **venues** function to get details of each restaurant, including **price**,  the count of **likes**, and their **rating**. The first two features are going to be used to contruct our indepedent variables, and the last one is used as our dependent variable in our multiple linear regression model.

# %% [markdown]
# #### 2.1. Get the latitude and longitude of a location

# %%
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# !pip install msgpack
# !pip install geocoder
import geocoder
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.0.2p             |       h470a237_1         3.1 MB  conda-forge
#     certifi-2018.10.15         |        py36_1000         138 KB  conda-forge
#     geopy-1.17.0               |             py_0          49 KB  conda-forge
#     ca-certificates-2018.10.15 |       ha4d7672_0         135 KB  conda-forge
#     conda-4.5.11               |        py36_1000         651 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0            conda-forge
#     geopy:           1.17.0-py_0          conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2018.8.24-ha4d7672_0 conda-forge --> 2018.10.15-ha4d7672_0 conda-forge
#     certifi:         2018.8.24-py36_1001  conda-forge --> 2018.10.15-py36_1000  conda-forge
#     conda:           4.5.11-py36_0        conda-forge --> 4.5.11-py36_1000      conda-forge
#     openssl:         1.0.2p-h470a237_0    conda-forge --> 1.0.2p-h470a237_1     conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.0.2p       | 3.1 MB    | ##################################### | 100%
# certifi-2018.10.15   | 138 KB    | ##################################### | 100%
# geopy-1.17.0         | 49 KB     | ##################################### | 100%
# ca-certificates-2018 | 135 KB    | ##################################### | 100%
# conda-4.5.11         | 651 KB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting msgpack
#   Downloading https://files.pythonhosted.org/packages/22/4e/dcf124fd97e5f5611123d6ad9f40ffd6eb979d1efdc1049e28a795672fcd/msgpack-0.5.6-cp36-cp36m-manylinux1_x86_64.whl (315kB)
#     100% |████████████████████████████████| 317kB 19.3MB/s
# Installing collected packages: msgpack
# Successfully installed msgpack-0.5.6
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#     100% |████████████████████████████████| 102kB 16.7MB/s
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: requests in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (2.18.4)
# Requirement already satisfied: future in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (0.16.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (1.11.0)
# Requirement already satisfied: click in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (6.7)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (2018.10.15)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
# Input a location. Default is North York, ON.
address = 'North York, ON'
geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(address, [latitude, longitude])
# Out:
# North York, ON [43.7709163, -79.4124102]

# %% [markdown]
# #### 2.2. Utilize the Foursquare API to explore the restaurants nearby

# %% [markdown]
# Define Foursquare Credentials and Version

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# Get the top 50 venues that are within a radius of 1,000 meters

# %%
VERSION = '20181105'
radius = 1000 # within 1000 meters
LIMIT = 50 # maximum 50 venues
SECTION = 'food' # restaurants

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&section={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT, SECTION)

# %% [markdown]
# Send the GET request and examine the resutls

# %%
import requests
results = requests.get(url).json()

# %%
count = len(results['response']['groups'][0]['items'])
def restaurant():
    if count <= 1:
        return 'restaurant' 
    else:
        return 'restaurants'

# %%
scope = round(radius/1000, 2)
if scope <= 1:
    km = 'km'
else:
    km = 'kms'

# %%
'{} {} are found within {} {} radius of {}.'.format(count, restaurant(), scope, km, address)
# Out:
# '50 restaurants are found within 1.0 km radius of North York, ON.'

# %% [markdown]
# Now we are ready to clean the json and structure it into a pandas dataframe

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '563d44fccd1044ad67a744fb',
#   'name': "The Captain's Boil",
#   'location': {'address': '5313 Yonge St',
#    'lat': 43.773255217045026,
#    'lng': -79.41380541792645,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.773255217045026,
#      'lng': -79.41380541792645}],
#    'distance': 283,
#    'postalCode': 'M2N 5R4',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['5313 Yonge St', 'Toronto ON M2N 5R4', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d1ce941735',
#     'name': 'Seafood Restaurant',
#     'pluralName': 'Seafood Restaurants',
#     'shortName': 'Seafood',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-3-563d44fccd1044ad67a744fb-0'}

# %% [markdown]
# Create a dataframe that contains all restaurants around the input location

# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
dataframe = json_normalize(items) # flatten JSON
dataframe.head()
# Out:
#    reasons.count                                      reasons.items  \
# 0              0  [{'summary': 'This spot is popular', 'type': '...
# 1              0  [{'summary': 'This spot is popular', 'type': '...
# 2              0  [{'summary': 'This spot is popular', 'type': '...
# 3              0  [{'summary': 'This spot is popular', 'type': '...
# 4              0  [{'summary': 'This spot is popular', 'type': '...
#
#                        referralId  \
# 0  e-3-563d44fccd1044ad67a744fb-0
# 1  e-3-5a35b4443abcaf37eb1a0d88-1
# 2  e-3-529f667511d2b09b2a210b5f-2
# 3  e-3-5a02789d0a464d3112a58785-3
# 4  e-3-53c7201c498ef6785edb6856-4
#
#                                     venue.categories  \
# 0  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...
# 1  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...
# 2  [{'id': '4bf58dd8d48988d153941735', 'name': 'B...
# 3  [{'id': '55a59bace4b013909087cb24', 'name': 'R...
# 4  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...
#
#                    venue.id venue.location.address venue.location.cc  \
# 0  563d44fccd1044ad67a744fb          5313 Yonge St                CA
# 1  5a35b4443abcaf37eb1a0d88                    NaN                CA
# 2  529f667511d2b09b2a210b5f          5314 Yonge St                CA
# 3  5a02789d0a464d3112a58785          5051 Yonge St                CA
# 4  53c7201c498ef6785edb6856          5310 Yonge St                CA
#
#   venue.location.city venue.location.country    venue.location.crossStreet  \
# 0             Toronto                 Canada                           NaN
# 1             Toronto                 Canada                           NaN
# 2             Toronto                 Canada                  at McKee Ave
# 3             Toronto                 Canada  btwn Elmwood & Hillcrest Ave
# 4                 NaN                 Canada                           NaN
#
#           ...                              venue.location.labeledLatLngs  \
# 0         ...          [{'label': 'display', 'lat': 43.77325521704502...
# 1         ...          [{'label': 'display', 'lat': 43.7665789176648,...
# 2         ...          [{'label': 'display', 'lat': 43.77305366245606...
# 3         ...          [{'label': 'display', 'lat': 43.76699771023422...
# 4         ...          [{'label': 'display', 'lat': 43.77300999884723...
#
#   venue.location.lat venue.location.lng  venue.location.neighborhood  \
# 0          43.773255         -79.413805                          NaN
# 1          43.766579         -79.412131                   Willowdale
# 2          43.773054         -79.414082                          NaN
# 3          43.766998         -79.412222                   Willowdale
# 4          43.773010         -79.413875                          NaN
#
#    venue.location.postalCode venue.location.state          venue.name  \
# 0                    M2N 5R4                   ON  The Captain's Boil
# 1                    M2N 5P1                   ON             The Keg
# 2                    M2N 6V1                   ON        Burrito Boyz
# 3                    M2N 5P2                   ON       Konjiki Ramen
# 4                    M2N 5P9                  NaN             Dakgogi
#
#   venue.photos.count venue.photos.groups  venue.venuePage.id
# 0                  0                  []                 NaN
# 1                  0                  []                 NaN
# 2                  0                  []                 NaN
# 3                  0                  []                 NaN
# 4                  0                  []                 NaN
#
# [5 rows x 22 columns]

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]
dataframe_filtered
# Out:
#                                     name                 categories  \
# 0                     The Captain's Boil         Seafood Restaurant
# 1                                The Keg                 Steakhouse
# 2                           Burrito Boyz              Burrito Place
# 3                          Konjiki Ramen           Ramen Restaurant
# 4                                Dakgogi          Korean Restaurant
# 5                     Aroma Espresso Bar                       Café
# 6                             Sushi Bong           Sushi Restaurant
# 7        Pastel Creperie & Dessert House                   Creperie
# 8   Buk Chang Dong Soon Tofu 북창동 순두부 돌솥밥          Korean Restaurant
# 9                  St. Louis Bar & Grill                Wings Joint
# 10                            Satay Sate      Indonesian Restaurant
# 11            Sushi Moto Sake & Wine Bar           Sushi Restaurant
# 12                        Owl of Minerva          Korean Restaurant
# 13                            Aburi Room           Sushi Restaurant
# 14                    Sansotei Ramen 三草亭           Ramen Restaurant
# 15                Hakata Shoryuken Ramen           Ramen Restaurant
# 16                   Ajisen Ramen 味千ラーメン           Ramen Restaurant
# 17                          MYMY Chicken        Fried Chicken Joint
# 18              Jack Astor's Bar & Grill                 Restaurant
# 19                           Baton Rouge        American Restaurant
# 20                        Bake Code 烘焙密碼                     Bakery
# 21    Symposium Cafe Restaurant & Lounge                 Restaurant
# 22                             Pizzaiolo                Pizza Place
# 23                             Sushi One        Japanese Restaurant
# 24                               The Fry        Fried Chicken Joint
# 25             Pho 88 Vietnamese Cuisine      Vietnamese Restaurant
# 26                                 Nolbu          Korean Restaurant
# 27                       Pyung Won House          Korean Restaurant
# 28                   Union Social Eatery                 Restaurant
# 29                        Haida Sandwich       Fast Food Restaurant
# 30                            Pizza Shab                Pizza Place
# 31                              Roll.com          Korean Restaurant
# 32                          KINTON RAMEN           Ramen Restaurant
# 33                          Boston Pizza                Pizza Place
# 34                               Wendy's       Fast Food Restaurant
# 35                     Artisan Noodle 老碗         Chinese Restaurant
# 36                      Wako Sushi + Bar        Japanese Restaurant
# 37                          Nomé Izakaya        Japanese Restaurant
# 38                                Subway             Sandwich Place
# 39                 Charcoal & Salt 숯과 소금          Korean Restaurant
# 40                                Subway             Sandwich Place
# 41                   Lee Town Restaurant         Chinese Restaurant
# 42                             Wild Wing                Wings Joint
# 43                          Yuzu Izakaya        Japanese Restaurant
# 44                          Shawarma Max  Middle Eastern Restaurant
# 45          Kiyomizu Japanese Restaurant        Japanese Restaurant
# 46                             Bar Koyoi        Japanese Restaurant
# 47                 Oh Geul Boh Geul 오글보글          Korean Restaurant
# 48                      Freshslice Pizza                Pizza Place
# 49                                Subway             Sandwich Place
#
#                    address  cc        city country  \
# 0            5313 Yonge St  CA     Toronto  Canada
# 1                      NaN  CA     Toronto  Canada
# 2            5314 Yonge St  CA     Toronto  Canada
# 3            5051 Yonge St  CA     Toronto  Canada
# 4            5310 Yonge St  CA         NaN  Canada
# 5               6 Parkhome  CA  North York  Canada
# 6          5 Northtown Way  CA     Toronto  Canada
# 7            5417 Yonge St  CA     Toronto  Canada
# 8           5445 Yonge St.  CA     Toronto  Canada
# 9           2050 Yonge St.  CA     Toronto  Canada
# 10           5025 Yonge St  CA  North York  Canada
# 11           4901 Yonge St  CA     Toronto  Canada
# 12           5324 Yonge St  CA     Toronto  Canada
# 13                     NaN  CA     Toronto  Canada
# 14             13 Byng Ave  CA     Toronto  Canada
# 15           5321 Yonge St  CA   Noth York  Canada
# 16          5229 Yonge St.  CA     Toronto  Canada
# 17     9 Spring Garden Ave  CA     Toronto  Canada
# 18           5051 Yonge St  CA     Toronto  Canada
# 19          5000 Yonge St.  CA  North York  Canada
# 20           4910 Yonge St  CA     Toronto  Canada
# 21           5221 Yonge St  CA   Northyork  Canada
# 22          4920 Yonge St.  CA     Toronto  Canada
# 23          4924 Yonge St.  CA     Toronto  Canada
# 24       4864 Yonge Street  CA         NaN  Canada
# 25           5197 Yonge St  CA     Toronto  Canada
# 26                     NaN  CA         NaN  Canada
# 27          5588 Yonge St.  CA     Toronto  Canada
# 28           4899 Yonge St  CA     Toronto  Canada
# 29        15 Northtown Way  CA     Toronto  Canada
# 30              3 Byng Ave  CA  North York  Canada
# 31    5 Northtown Way, #10  CA     Toronto  Canada
# 32           5165 Yonge St  CA  North York  Canada
# 33           5170 Yonge St  CA     Toronto  Canada
# 34       5095 Yonge Street  CA  North York  Canada
# 35           5431 Yonge St  CA     Toronto  Canada
# 36       5213 Yonge Street  CA  North York  Canada
# 37           4848 Yonge St  CA     Toronto  Canada
# 38          5225 Yonge St.  CA     Toronto  Canada
# 39           5523 Yonge St  CA     Toronto  Canada
# 40  5150 Yonge St. Unit F3  CA     Toronto  Canada
# 41          4907 Yonge St.  CA     Toronto  Canada
# 42          5505 Yonge St.  CA     Toronto  Canada
# 43          5582 Yonge St.  CA     Toronto  Canada
# 44          4969 Yonge St.  CA     Toronto  Canada
# 45   41 Spring Garden Ave.  CA  North York  Canada
# 46           5347 Yonge St  CA  North York  Canada
# 47           5320 Yonge St  CA     Toronto  Canada
# 48       5223 Yonge Street  CA     Toronto  Canada
# 49          4936 Yonge St.  CA     Toronto  Canada
#
#                          crossStreet  distance  \
# 0                                NaN       283
# 1                                NaN       483
# 2                       at McKee Ave       273
# 3       btwn Elmwood & Hillcrest Ave       436
# 4                                NaN       261
# 5                                NaN       172
# 6                        at Yonge St       512
# 7                      at Finch Ave.       617
# 8                  at Kempford Blvd.       728
# 9                                NaN       260
# 10                    at Elmwood Ave       471
# 11                  Yonge & Sheppard       783
# 12                  at Churchill Ave       294
# 13                               NaN       231
# 14                      at Doris Ave       656
# 15                      at Church St       312
# 16                  at Parkview Ave.        82
# 17                       at Yonge St       704
# 18          btwn Hillcrest & Elmwood       425
# 19                               NaN       496
# 20              at Spring Garden Ave       775
# 21                          Parkview        81
# 22                Spring Garden Ave.       739
# 23                               NaN       725
# 24                               NaN       885
# 25                   at Empress Walk        73
# 26                               NaN       878
# 27                     at Finch Ave.       975
# 28                Yonge and Sheppard       797
# 29                      Yonge Street       511
# 30                             Yonge       651
# 31                               NaN       508
# 32                  Kingsdale Avenue       146
# 33                    at Empress Ave       148
# 34  btwn Empress Ave & Hillcrest Ave       273
# 35                       at Byng Ave       621
# 36                               NaN        59
# 37                               NaN       933
# 38                  at Parkview Ave.        99
# 39                               NaN       861
# 40         in North York City Centre       321
# 41             at Spring Garden Ave.       750
# 42                    at Holmes Ave.       814
# 43                        Finch Ave.       968
# 44                     Hollywood Ave       560
# 45                      at Yonge St.       703
# 46                               NaN       473
# 47                            Church       276
# 48                     Yonge & Finch        99
# 49             ay Upper Madison Ave.       711
#
#                                      formattedAddress  \
# 0         [5313 Yonge St, Toronto ON M2N 5R4, Canada]
# 1                        [Toronto ON M2N 5P1, Canada]
# 2   [5314 Yonge St (at McKee Ave), Toronto ON M2N ...
# 3   [5051 Yonge St (btwn Elmwood & Hillcrest Ave),...
# 4                    [5310 Yonge St, M2N 5P9, Canada]
# 5                 [6 Parkhome, North York ON, Canada]
# 6   [5 Northtown Way (at Yonge St), Toronto ON M2N...
# 7   [5417 Yonge St (at Finch Ave.), Toronto ON M2N...
# 8   [5445 Yonge St. (at Kempford Blvd.), Toronto O...
# 9        [2050 Yonge St., Toronto ON M4S 1Z9, Canada]
# 10  [5025 Yonge St (at Elmwood Ave), North York ON...
# 11  [4901 Yonge St (Yonge & Sheppard), Toronto ON ...
# 12  [5324 Yonge St (at Churchill Ave), Toronto ON ...
# 13                       [Toronto ON M2N 0J4, Canada]
# 14  [13 Byng Ave (at Doris Ave), Toronto ON M2N 5R...
# 15  [5321 Yonge St (at Church St), Noth York ON M2...
# 16  [5229 Yonge St. (at Parkview Ave.), Toronto ON...
# 17  [9 Spring Garden Ave (at Yonge St), Toronto ON...
# 18  [5051 Yonge St (btwn Hillcrest & Elmwood), Tor...
# 19    [5000 Yonge St., North York ON M2N 7E9, Canada]
# 20  [4910 Yonge St (at Spring Garden Ave), Toronto...
# 21  [5221 Yonge St (Parkview), Northyork ON M2N 5P...
# 22  [4920 Yonge St. (Spring Garden Ave.), Toronto ...
# 23       [4924 Yonge St., Toronto ON M2N 5N5, Canada]
# 24               [4864 Yonge Street, M2N 5N2, Canada]
# 25  [5197 Yonge St (at Empress Walk), Toronto ON, ...
# 26                                           [Canada]
# 27  [5588 Yonge St. (at Finch Ave.), Toronto ON M2...
# 28  [4899 Yonge St (Yonge and Sheppard), Toronto O...
# 29  [15 Northtown Way (Yonge Street), Toronto ON M...
# 30  [3 Byng Ave (Yonge), North York ON M2N 0E6, Ca...
# 31         [5 Northtown Way, #10, Toronto ON, Canada]
# 32  [5165 Yonge St (Kingsdale Avenue), North York ...
# 33  [5170 Yonge St (at Empress Ave), Toronto ON M2...
# 34  [5095 Yonge Street (btwn Empress Ave & Hillcre...
# 35  [5431 Yonge St (at Byng Ave), Toronto ON M2N 5...
# 36         [5213 Yonge Street, North York ON, Canada]
# 37                [4848 Yonge St, Toronto ON, Canada]
# 38  [5225 Yonge St. (at Parkview Ave.), Toronto ON...
# 39                [5523 Yonge St, Toronto ON, Canada]
# 40  [5150 Yonge St. Unit F3 (in North York City Ce...
# 41  [4907 Yonge St. (at Spring Garden Ave.), Toron...
# 42  [5505 Yonge St. (at Holmes Ave.), Toronto ON M...
# 43  [5582 Yonge St. (Finch Ave.), Toronto ON M2N 5...
# 44  [4969 Yonge St. (Hollywood Ave), Toronto ON, C...
# 45  [41 Spring Garden Ave. (at Yonge St.), North Y...
# 46     [5347 Yonge St, North York ON M2N 7A1, Canada]
# 47  [5320 Yonge St (Church), Toronto ON M2N 5P9, C...
# 48  [5223 Yonge Street (Yonge & Finch), Toronto ON...
# 49  [4936 Yonge St. (ay Upper Madison Ave.), Toron...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 43.77325521704502...  43.773255 -79.413805
# 1   [{'label': 'display', 'lat': 43.7665789176648,...  43.766579 -79.412131
# 2   [{'label': 'display', 'lat': 43.77305366245606...  43.773054 -79.414082
# 3   [{'label': 'display', 'lat': 43.76699771023422...  43.766998 -79.412222
# 4   [{'label': 'display', 'lat': 43.77300999884723...  43.773010 -79.413875
# 5   [{'label': 'display', 'lat': 43.76944882099181...  43.769449 -79.413081
# 6   [{'label': 'display', 'lat': 43.77542805510968...  43.775428 -79.413654
# 7   [{'label': 'display', 'lat': 43.77621893353755...  43.776219 -79.414648
# 8   [{'label': 'display', 'lat': 43.77721927435775...  43.777219 -79.414861
# 9   [{'label': 'display', 'lat': 43.77304026482439...  43.773040 -79.413771
# 10  [{'label': 'display', 'lat': 43.76669, 'lng': ...  43.766690 -79.412100
# 11  [{'label': 'display', 'lat': 43.76390159157955...  43.763902 -79.411559
# 12  [{'label': 'display', 'lat': 43.77332781286471...  43.773328 -79.413915
# 13  [{'label': 'display', 'lat': 43.769197, 'lng':...  43.769197 -79.414039
# 14  [{'label': 'display', 'lat': 43.77670850946814...  43.776709 -79.413927
# 15  [{'label': 'display', 'lat': 43.77351855289592...  43.773519 -79.413872
# 16  [{'label': 'display', 'lat': 43.771444, 'lng':...  43.771444 -79.413139
# 17  [{'label': 'display', 'lat': 43.76465797243293...  43.764658 -79.411096
# 18  [{'label': 'display', 'lat': 43.76709662310871...  43.767097 -79.412263
# 19  [{'label': 'display', 'lat': 43.76645494997892...  43.766455 -79.412229
# 20  [{'label': 'display', 'lat': 43.76396880903952...  43.763969 -79.411641
# 21  [{'label': 'display', 'lat': 43.77107544003332...  43.771075 -79.413396
# 22  [{'label': 'display', 'lat': 43.76428931934003...  43.764289 -79.411780
# 23  [{'label': 'display', 'lat': 43.76441166173842...  43.764412 -79.411880
# 24  [{'label': 'display', 'lat': 43.76299303331066...  43.762993 -79.411442
# 25  [{'label': 'display', 'lat': 43.77045596393368...  43.770456 -79.413064
# 26  [{'label': 'display', 'lat': 43.76302920514094...  43.763029 -79.411937
# 27  [{'label': 'display', 'lat': 43.77938630849616...  43.779386 -79.415511
# 28  [{'label': 'display', 'lat': 43.76379660470405...  43.763797 -79.411358
# 29  [{'label': 'display', 'lat': 43.77543167870811...  43.775432 -79.413587
# 30  [{'label': 'display', 'lat': 43.77662520025942...  43.776625 -79.414201
# 31  [{'label': 'display', 'lat': 43.77528800664203...  43.775288 -79.414256
# 32  [{'label': 'display', 'lat': 43.76968375926793...  43.769684 -79.413049
# 33  [{'label': 'display', 'lat': 43.76966566980136...  43.769666 -79.413057
# 34  [{'label': 'display', 'lat': 43.76846127243853...  43.768461 -79.412377
# 35  [{'label': 'display', 'lat': 43.77626534484827...  43.776265 -79.414630
# 36  [{'label': 'display', 'lat': 43.77080606720809...  43.770806 -79.413138
# 37  [{'label': 'display', 'lat': 43.76255929292571...  43.762559 -79.411440
# 38  [{'label': 'display', 'lat': 43.77140090446779...  43.771401 -79.413457
# 39  [{'label': 'display', 'lat': 43.77838235992638...  43.778382 -79.415240
# 40  [{'label': 'display', 'lat': 43.76817581386525...  43.768176 -79.413674
# 41  [{'label': 'display', 'lat': 43.76419503107473...  43.764195 -79.411626
# 42  [{'label': 'display', 'lat': 43.77801245521090...  43.778012 -79.414884
# 43  [{'label': 'display', 'lat': 43.77929585003712...  43.779296 -79.415655
# 44  [{'label': 'display', 'lat': 43.76601170897119...  43.766012 -79.410844
# 45  [{'label': 'display', 'lat': 43.7648196440823,...  43.764820 -79.410106
# 46  [{'label': 'display', 'lat': 43.77494335172162...  43.774943 -79.414306
# 47  [{'label': 'display', 'lat': 43.77315120705706...  43.773151 -79.413915
# 48  [{'label': 'display', 'lat': 43.77135340802530...  43.771353 -79.413487
# 49  [{'label': 'display', 'lat': 43.76454181201586...  43.764542 -79.411726
#
#    neighborhood postalCode state                        id
# 0           NaN    M2N 5R4    ON  563d44fccd1044ad67a744fb
# 1    Willowdale    M2N 5P1    ON  5a35b4443abcaf37eb1a0d88
# 2           NaN    M2N 6V1    ON  529f667511d2b09b2a210b5f
# 3    Willowdale    M2N 5P2    ON  5a02789d0a464d3112a58785
# 4           NaN    M2N 5P9   NaN  53c7201c498ef6785edb6856
# 5           NaN        NaN    ON  557767bc498ea4a20c8043f6
# 6           NaN    M2N 7A1    ON  4b2c1999f964a52098c124e3
# 7           NaN    M2N 5R6    ON  4d446252e198721e4c23bb8b
# 8           NaN    M2N 5S1    ON  4b5c97d1f964a520a83829e3
# 9           NaN    M4S 1Z9    ON  4b590484f964a520b27828e3
# 10          NaN    M2N 5P2    ON  57f92db0498ee70159702002
# 11          NaN    M2N 5N4    ON  4c12ccc077cea59360c0cd60
# 12          NaN     Canada    ON  4b2ea56cf964a52034e424e3
# 13          NaN    M2N 0J4    ON  5ab5accd6bd36b087487be93
# 14   Willowdale    M2N 5R7    ON  58a0ab8004f4d7127735a1ce
# 15          NaN    M2N 5R4    ON  543d5b07498e006131fa3449
# 16          NaN    M2N 5P8    ON  4b315d90f964a520840525e3
# 17          NaN    M2N 3G1    ON  58702ed20bc55b0a672ae4e6
# 18          NaN    M2N 5P2    ON  514bcaf7b0ede37f9e7d89d4
# 19          NaN    M2N 7E9    ON  4b3e93dcf964a520309f25e3
# 20          NaN    M2N 5N5    ON  55d4174a498e4282465852fd
# 21          NaN    M2N 5P8    ON  537befcc498edb1da559269b
# 22          NaN    M2N 5N5    ON  4dcc56ac1838a9a8d7fe67fc
# 23          NaN    M2N 5N5    ON  4c76920adb52b1f7a0c97bdc
# 24          NaN    M2N 5N2   NaN  52fae3ef11d28f827283ff95
# 25          NaN        NaN    ON  4b4779f0f964a520543326e3
# 26          NaN        NaN   NaN  53377fbc498e2f346e290036
# 27          NaN    M2N 6B1    ON  4df2bb3662e1288ed301a91b
# 28          NaN    M2N 5N4    ON  559863b3498e5df666bf37ad
# 29          NaN    M2N 7A2    ON  4e2f7e22d1646b407b8f1651
# 30          NaN    M2N 0E6    ON  5096aff6f31cf044e81a21ea
# 31          NaN        NaN    ON  4d892f62401a224b6ba68718
# 32          NaN    M2N 5P5    ON  544ad69a498eeb86b7a4a8d0
# 33   Willowdale    M2N 5X2    ON  5896720a469aef72f336fb7e
# 34          NaN    M2N 6Z4    ON  4b832e14f964a5200dfc30e3
# 35          NaN    M2N 5R6    ON  5532ead9498e3cd7914f75ee
# 36          NaN        NaN    ON  5077025ce4b05aefca37d9f9
# 37          NaN        NaN    ON  4fc6d475e4b0785353957fe7
# 38          NaN        M2N    ON  4c6d9c254d24b60caa5ed6d8
# 39          NaN        NaN    ON  4cedadac4cd4236ad290a963
# 40          NaN    M2N 6L7    ON  511143a6e4b07cf13ef1b50b
# 41          NaN    M2N 5N4    ON  4bec2d59415e20a14830e7bb
# 42          NaN    M2N 5S3    ON  4de1408152b1c1b3ce47c641
# 43          NaN    M2N 5S2    ON  517c753fe4b033d3ae281ef7
# 44          NaN        NaN    ON  4bb628fbef159c74e18075f7
# 45          NaN        NaN    ON  4b671ac9f964a520d73a2be3
# 46          NaN    M2N 7A1    ON  53365b04498e1331002e4d2c
# 47          NaN    M2N 5P9    ON  4b410a86f964a520e7bf25e3
# 48          NaN    M2N 5P8    ON  4ce3129c4df7a35d66c9e079
# 49          NaN    M2N 5N5    ON  4d9f526a5dc7f04d62056c91

# %% [markdown]
# #### 2.3. Collect **venues** data of each restaurant, including **price**,  the count of **likes**, the count of **tips**, and their **rating**

# %%
ratings = list()
prices = list()
likes = list()
tips = list()

for venue_id in dataframe_filtered.id:
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    try:
        ratings.append(result['response']['venue']['rating'])
    except:
        ratings.append(None)
    try:
        prices.append(result['response']['venue']['price']['tier'])
    except:
        prices.append(None)
    try:
        likes.append(result['response']['venue']['likes']['count'])
    except:
        likes.append(None)
    try:
        tips.append(result['response']['venue']['stats']['tipCount'])
    except:
        tips.append(None)

dataframe_filtered['rating'] = ratings
dataframe_filtered['price'] = prices
dataframe_filtered['likes'] = likes

# %%
restaurant = dataframe_filtered[['name','categories', 'address', 'postalCode', 'lat', 'lng', 'price', 'likes', 'rating']]
restaurant
# Out:
#                                     name                 categories  \
# 0                     The Captain's Boil         Seafood Restaurant
# 1                                The Keg                 Steakhouse
# 2                           Burrito Boyz              Burrito Place
# 3                          Konjiki Ramen           Ramen Restaurant
# 4                                Dakgogi          Korean Restaurant
# 5                     Aroma Espresso Bar                       Café
# 6                             Sushi Bong           Sushi Restaurant
# 7        Pastel Creperie & Dessert House                   Creperie
# 8   Buk Chang Dong Soon Tofu 북창동 순두부 돌솥밥          Korean Restaurant
# 9                  St. Louis Bar & Grill                Wings Joint
# 10                            Satay Sate      Indonesian Restaurant
# 11            Sushi Moto Sake & Wine Bar           Sushi Restaurant
# 12                        Owl of Minerva          Korean Restaurant
# 13                            Aburi Room           Sushi Restaurant
# 14                    Sansotei Ramen 三草亭           Ramen Restaurant
# 15                Hakata Shoryuken Ramen           Ramen Restaurant
# 16                   Ajisen Ramen 味千ラーメン           Ramen Restaurant
# 17                          MYMY Chicken        Fried Chicken Joint
# 18              Jack Astor's Bar & Grill                 Restaurant
# 19                           Baton Rouge        American Restaurant
# 20                        Bake Code 烘焙密碼                     Bakery
# 21    Symposium Cafe Restaurant & Lounge                 Restaurant
# 22                             Pizzaiolo                Pizza Place
# 23                             Sushi One        Japanese Restaurant
# 24                               The Fry        Fried Chicken Joint
# 25             Pho 88 Vietnamese Cuisine      Vietnamese Restaurant
# 26                                 Nolbu          Korean Restaurant
# 27                       Pyung Won House          Korean Restaurant
# 28                   Union Social Eatery                 Restaurant
# 29                        Haida Sandwich       Fast Food Restaurant
# 30                            Pizza Shab                Pizza Place
# 31                              Roll.com          Korean Restaurant
# 32                          KINTON RAMEN           Ramen Restaurant
# 33                          Boston Pizza                Pizza Place
# 34                               Wendy's       Fast Food Restaurant
# 35                     Artisan Noodle 老碗         Chinese Restaurant
# 36                      Wako Sushi + Bar        Japanese Restaurant
# 37                          Nomé Izakaya        Japanese Restaurant
# 38                                Subway             Sandwich Place
# 39                 Charcoal & Salt 숯과 소금          Korean Restaurant
# 40                                Subway             Sandwich Place
# 41                   Lee Town Restaurant         Chinese Restaurant
# 42                             Wild Wing                Wings Joint
# 43                          Yuzu Izakaya        Japanese Restaurant
# 44                          Shawarma Max  Middle Eastern Restaurant
# 45          Kiyomizu Japanese Restaurant        Japanese Restaurant
# 46                             Bar Koyoi        Japanese Restaurant
# 47                 Oh Geul Boh Geul 오글보글          Korean Restaurant
# 48                      Freshslice Pizza                Pizza Place
# 49                                Subway             Sandwich Place
#
#                    address postalCode        lat        lng  price  likes  \
# 0            5313 Yonge St    M2N 5R4  43.773255 -79.413805    3.0     41
# 1                      NaN    M2N 5P1  43.766579 -79.412131    4.0     17
# 2            5314 Yonge St    M2N 6V1  43.773054 -79.414082    2.0     43
# 3            5051 Yonge St    M2N 5P2  43.766998 -79.412222    NaN     25
# 4            5310 Yonge St    M2N 5P9  43.773010 -79.413875    2.0     11
# 5               6 Parkhome        NaN  43.769449 -79.413081    1.0     17
# 6          5 Northtown Way    M2N 7A1  43.775428 -79.413654    2.0     67
# 7            5417 Yonge St    M2N 5R6  43.776219 -79.414648    2.0     64
# 8           5445 Yonge St.    M2N 5S1  43.777219 -79.414861    1.0     98
# 9           2050 Yonge St.    M4S 1Z9  43.773040 -79.413771    2.0     60
# 10           5025 Yonge St    M2N 5P2  43.766690 -79.412100    2.0      7
# 11           4901 Yonge St    M2N 5N4  43.763902 -79.411559    2.0    102
# 12           5324 Yonge St     Canada  43.773328 -79.413915    1.0     57
# 13                     NaN    M2N 0J4  43.769197 -79.414039    2.0      6
# 14             13 Byng Ave    M2N 5R7  43.776709 -79.413927    NaN     12
# 15           5321 Yonge St    M2N 5R4  43.773519 -79.413872    NaN     21
# 16          5229 Yonge St.    M2N 5P8  43.771444 -79.413139    NaN     52
# 17     9 Spring Garden Ave    M2N 3G1  43.764658 -79.411096    1.0     10
# 18           5051 Yonge St    M2N 5P2  43.767097 -79.412263    2.0    140
# 19          5000 Yonge St.    M2N 7E9  43.766455 -79.412229    3.0     29
# 20           4910 Yonge St    M2N 5N5  43.763969 -79.411641    1.0     49
# 21           5221 Yonge St    M2N 5P8  43.771075 -79.413396    2.0     28
# 22          4920 Yonge St.    M2N 5N5  43.764289 -79.411780    1.0      8
# 23          4924 Yonge St.    M2N 5N5  43.764412 -79.411880    3.0     42
# 24       4864 Yonge Street    M2N 5N2  43.762993 -79.411442    1.0     19
# 25           5197 Yonge St        NaN  43.770456 -79.413064    2.0     27
# 26                     NaN        NaN  43.763029 -79.411937    2.0      9
# 27          5588 Yonge St.    M2N 6B1  43.779386 -79.415511    2.0     15
# 28           4899 Yonge St    M2N 5N4  43.763797 -79.411358    2.0     47
# 29        15 Northtown Way    M2N 7A2  43.775432 -79.413587    1.0     17
# 30              3 Byng Ave    M2N 0E6  43.776625 -79.414201    1.0      8
# 31    5 Northtown Way, #10        NaN  43.775288 -79.414256    2.0      5
# 32           5165 Yonge St    M2N 5P5  43.769684 -79.413049    NaN     55
# 33           5170 Yonge St    M2N 5X2  43.769666 -79.413057    1.0      4
# 34       5095 Yonge Street    M2N 6Z4  43.768461 -79.412377    1.0     11
# 35           5431 Yonge St    M2N 5R6  43.776265 -79.414630    1.0     12
# 36       5213 Yonge Street        NaN  43.770806 -79.413138    2.0      8
# 37           4848 Yonge St        NaN  43.762559 -79.411440    2.0     61
# 38          5225 Yonge St.        M2N  43.771401 -79.413457    1.0      1
# 39           5523 Yonge St        NaN  43.778382 -79.415240    2.0      5
# 40  5150 Yonge St. Unit F3    M2N 6L7  43.768176 -79.413674    1.0      2
# 41          4907 Yonge St.    M2N 5N4  43.764195 -79.411626    1.0      2
# 42          5505 Yonge St.    M2N 5S3  43.778012 -79.414884    1.0     24
# 43          5582 Yonge St.    M2N 5S2  43.779296 -79.415655    2.0     10
# 44          4969 Yonge St.        NaN  43.766012 -79.410844    2.0     10
# 45   41 Spring Garden Ave.        NaN  43.764820 -79.410106    2.0     15
# 46           5347 Yonge St    M2N 7A1  43.774943 -79.414306    2.0      7
# 47           5320 Yonge St    M2N 5P9  43.773151 -79.413915    2.0     25
# 48       5223 Yonge Street    M2N 5P8  43.771353 -79.413487    1.0      5
# 49          4936 Yonge St.    M2N 5N5  43.764542 -79.411726    1.0      1
#
#     rating
# 0      8.1
# 1      8.5
# 2      7.8
# 3      8.0
# 4      7.6
# 5      7.5
# 6      7.9
# 7      8.2
# 8      8.4
# 9      7.3
# 10     7.5
# 11     8.3
# 12     7.2
# 13     7.1
# 14     7.6
# 15     7.1
# 16     6.9
# 17     7.7
# 18     7.1
# 19     7.1
# 20     7.5
# 21     6.7
# 22     7.3
# 23     7.2
# 24     7.4
# 25     6.6
# 26     7.3
# 27     7.5
# 28     7.2
# 29     6.8
# 30     7.0
# 31     6.8
# 32     6.5
# 33     6.4
# 34     6.5
# 35     6.8
# 36     6.4
# 37     7.2
# 38     6.3
# 39     7.0
# 40     6.4
# 41     6.7
# 42     6.7
# 43     6.9
# 44     6.4
# 45     6.5
# 46     6.3
# 47     6.1
# 48     6.0
# 49     6.4
